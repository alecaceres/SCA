# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from control.matlab import *
from matplotlib import pyplot as plt

# %% [markdown]
# ### Se ingresa la planta

# %%
s = tf("s")
G = 10/((s+2)*(s+5))
print("G = ")
G
# Out:
# G =
#       10
# --------------
# s^2 + 7 s + 10

# %% [markdown]
# ### Fórmulas necesarias:
# #### Tiempo de establecimiento:
# $t_s = \frac{\pi}{w_n\times \sqrt{1 - \zeta^2}}$
#
# ![image.png](attachment:image.png)

# %%
Yout, t = step(G)
plt.figure(figsize=(12,8))
plt.plot(t,Yout)
plt.title("Respuesta al escalón")
plt.xlabel("t (time)")
plt.ylabel("response")
plt.grid(alpha = 0.4)
plt.show()

# %%
polo = -3+2j
empanada, algo = rlocus(G,pd = polo, xlim=(-6,-1), ylim=(-6,6),aspect = 12)

# %%
sisotool(G)
